# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/admin/OneDrive/Pictures/OneDrive/Desktop/bangalore house price prediction .csv")

# %%
data
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0        3      2.0  150.00          1672.0    3     8971.291866
# 1        3      3.0  149.00          1750.0    3     8514.285714
# 2        3      2.0  150.00          1750.0    3     8571.428571
# 3        2      2.0   40.00          1250.0    2     3200.000000
# 4        2      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115     3      2.0  325.00          2900.0    3    11206.896550
# 7116     3      1.0   84.83          1780.0    3     4765.730337
# 7117     2      1.0   48.00           880.0    2     5454.545455
# 7118     2      1.0   55.00          1000.0    2     5500.000000
# 7119     2      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
### printing shape of dataframe
data.shape
# Out:
# (7120, 108)

# %% [markdown]
# #### Exploratery data analysis (EDA)

# %%
## number of columns in the dataset
data.columns
# Out:
# Index(['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft',
#        'area_typeSuper built-up  Area', 'area_typeBuilt-up  Area',
#        'area_typePlot  Area', 'availability_Ready To Move',
#        ...
#        'location_Kalena Agrahara', 'location_Horamavu Agara',
#        'location_Vidyaranyapura', 'location_BTM 2nd Stage',
#        'location_Hebbal Kempapura', 'location_Hosur Road',
#        'location_Horamavu Banaswadi', 'location_Domlur',
#        'location_Mahadevpura', 'location_Tumkur Road'],
#       dtype='object', length=108)

# %%
df = data

# %%
df.head(4)
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0     3      2.0  150.0          1672.0    3     8971.291866
# 1     3      3.0  149.0          1750.0    3     8514.285714
# 2     3      2.0  150.0          1750.0    3     8571.428571
# 3     2      2.0   40.0          1250.0    2     3200.000000
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# 3                    0                           1  ...
#
# ...

# %%
x = df.iloc[:,0:-1].values ## we have creat x and y
x
# Out:
# array([[  3.,   2., 150., ...,   0.,   0.,   0.],
#        [  3.,   3., 149., ...,   0.,   0.,   0.],
#        [  3.,   2., 150., ...,   0.,   0.,   0.],
#        ...,
#        [  2.,   1.,  48., ...,   0.,   0.,   0.],
#        [  2.,   1.,  55., ...,   0.,   0.,   0.],
#        [  2.,   1.,  78., ...,   0.,   0.,   0.]])

# %%
y = df.iloc[0:1].values
y
# Out:
# array([[3.00000000e+00, 2.00000000e+00, 1.50000000e+02, 1.67200000e+03,
#         3.00000000e+00, 8.97129187e+03, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %% [markdown]
# #### printing shape of x and y

# %%
x.shape
# Out:
# (7120, 107)

# %%
y.shape
# Out:
# (1, 108)

# %%
x = df.drop('price',axis=1)
y = df['price']

# %%
print('shape of x= ', x.shape)
print('shape of  y = ', y.shape)
# Out:
# shape of x=  (7120, 107)
# shape of  y =  (7120,)

# %%
## information about dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Columns: 108 entries, bath to location_Tumkur Road
# dtypes: float64(4), int64(104)
# memory usage: 5.9 MB

# %%
df.describe()
# Out:
#               bath      balcony        price  total_sqft_int          bhk  \
# count  7120.000000  7120.000000  7120.000000     7120.000000  7120.000000
# mean      2.390871     1.572759    96.454991     1479.729806     2.465169
# std       0.876822     0.770583   116.185034      913.779769     0.841520
# min       1.000000     0.000000    10.000000      350.000000     1.000000
# 25%       2.000000     1.000000    49.230000     1100.000000     2.000000
# 50%       2.000000     2.000000    69.000000     1255.000000     2.000000
# 75%       3.000000     2.000000   104.000000     1640.250000     3.000000
# max       9.000000     3.000000  2912.000000    30400.000000     9.000000
#
#        price_per_sqft  area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# count     7120.000000                    7120.000000              7120.000000
# mean      5923.806855                       0.750702                 0.182303
# ...

# %%
## checking the some null value or not
df.isnull()
# Out:
#        bath  balcony  price  total_sqft_int    bhk  price_per_sqft  \
# 0     False    False  False           False  False           False
# 1     False    False  False           False  False           False
# 2     False    False  False           False  False           False
# 3     False    False  False           False  False           False
# 4     False    False  False           False  False           False
# ...     ...      ...    ...             ...    ...             ...
# 7115  False    False  False           False  False           False
# 7116  False    False  False           False  False           False
# 7117  False    False  False           False  False           False
# 7118  False    False  False           False  False           False
# 7119  False    False  False           False  False           False
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                             False                    False
# ...

# %% [markdown]
# #### data cleaning

# %%
df = data.isnull().sum()

df
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
data.isna().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %% [markdown]
# #### Drop Some Features

# %%
data.drop(['location_Whitefield','location_Electronic City','availability_Ready To Move','location_Marathahalli','location_Raja Rajeshwari Nagar'],axis='columns')
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0        3      2.0  150.00          1672.0    3     8971.291866
# 1        3      3.0  149.00          1750.0    3     8514.285714
# 2        3      2.0  150.00          1750.0    3     8571.428571
# 3        2      2.0   40.00          1250.0    2     3200.000000
# 4        2      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115     3      2.0  325.00          2900.0    3    11206.896550
# 7116     3      1.0   84.83          1780.0    3     4765.730337
# 7117     2      1.0   48.00           880.0    2     5454.545455
# 7118     2      1.0   55.00          1000.0    2     5500.000000
# 7119     2      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
data.shape
# Out:
# (7120, 108)

# %%
data.head
# Out:
# <bound method NDFrame.head of       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0        3      2.0  150.00          1672.0    3     8971.291866
# 1        3      3.0  149.00          1750.0    3     8514.285714
# 2        3      2.0  150.00          1750.0    3     8571.428571
# 3        2      2.0   40.00          1250.0    2     3200.000000
# 4        2      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115     3      2.0  325.00          2900.0    3    11206.896550
# 7116     3      1.0   84.83          1780.0    3     4765.730337
# 7117     2      1.0   48.00           880.0    2     5454.545455
# 7118     2      1.0   55.00          1000.0    2     5500.000000
# 7119     2      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
df1 = data.dropna()
df1.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
df1.shape
# Out:
# (7120, 108)

# %% [markdown]
# ###  Training And Testing Our Model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=51)

# %%
x_train
# Out:
#       bath  balcony  total_sqft_int  bhk  price_per_sqft  \
# 7112     5      2.0          2500.0    6     7400.000000
# 2169     2      0.0           995.0    2     4623.115578
# 47       2      2.0          1180.0    2     7500.000000
# 446      2      1.0          1450.0    3     5862.068966
# 2650     2      1.0          1197.0    2     6432.748538
# ...    ...      ...             ...  ...             ...
# 6672     2      1.0          1246.0    2     5457.463884
# 1733     2      1.0          1010.0    2     5742.574257
# 1760     2      2.0          1080.0    2     4629.629630
# 485      2      2.0           982.0    2     2500.000000
# 2105     2      1.0          1000.0    2     2888.000000
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 7112                              0                        1
# 2169                              0                        1
# 47                                1                        0
# ...

# %%
y_train
# Out:
# 7112    185.00
# 2169     46.00
# 47       88.50
# 446      85.00
# 2650     77.00
#          ...
# 6672     68.00
# 1733     58.00
# 1760     50.00
# 485      24.55
# 2105     28.88
# Name: price, Length: 5696, dtype: float64

# %%
x_train.shape
# Out:
# (5696, 107)

# %%
from sklearn.linear_model import LinearRegression

# %%
LinReg = LinearRegression() 
LinReg
# Out:
# LinearRegression()

# %%
 ###  we have fit our model
LinReg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinReg.coef_
LinReg.intercept_
# Out:
# -127.23946860161394

# %%
pred_LinReg = LinReg.predict(x_test)### we have find the predict value
pred_LinReg
# Out:
# array([ 76.90661876,  15.25005377, 113.68281651, ...,  21.30296863,
#         71.43462963, 230.04146251])

# %%
x_test
# Out:
#       bath   balcony  total_sqft_int  bhk  price_per_sqft  \
# 2435     3  1.584376          1700.0    3     4705.882353
# 3113     2  2.000000          1016.0    2     3937.007874
# 426      4  2.000000          1950.0    3     6153.846154
# 1124     2  1.000000          1350.0    2     5851.851852
# 1161     2  1.000000           850.0    2     5294.117647
# ...    ...       ...             ...  ...             ...
# 2078     2  1.000000          1090.0    2     2600.000000
# 6855     3  1.000000          1585.0    3     5299.684543
# 4381     1  2.000000           665.0    1     4812.030075
# 3862     2  1.000000          1167.0    2     5398.457584
# 43       2  0.000000          1566.0    2    11494.252870
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 2435                              0                        1
# 3113                              1                        0
# 426                               1                        0
# ...

# %%
y_test
# Out:
# 2435     80.00
# 3113     40.00
# 426     120.00
# 1124     79.00
# 1161     45.00
#          ...
# 2078     28.34
# 6855     84.00
# 4381     32.00
# 3862     63.00
# 43      180.00
# Name: price, Length: 1424, dtype: float64

# %%
import seaborn as sns
from sklearn.metrics import r2_score

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# %%
df
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
df.head()
# Out:
# bath              0
# balcony           0
# price             0
# total_sqft_int    0
# bhk               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# 0

# %%
df = df.fillna(0)

# %%
## standared method to choose the k
#### sqrt(n)
from math import sqrt

# %% [markdown]
# ## Banglore House Price Prediction

# %%
df
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=3)
                                         ### we have predict the model
knn.fit(x_train,y_train)
pred = knn.predict(x_test)

knn.score(x_test,y_test)
# Out:
# 0.907787835776612

# %% [markdown]
# #### Predict The Value Of House

# %%
x_test.iloc[-1,:]
# Out:
# bath                               2.00000
# balcony                            0.00000
# total_sqft_int                  1566.00000
# bhk                                2.00000
# price_per_sqft                 11494.25287
#                                   ...
# location_Hosur Road                0.00000
# location_Horamavu Banaswadi        0.00000
# location_Domlur                    0.00000
# location_Mahadevpura               0.00000
# location_Tumkur Road               0.00000
# Name: 43, Length: 107, dtype: float64

# %%
knn.predict([x_test.iloc[-1,:]])
# Out:
# C:\ProgramData\Anaconda1\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([180.66666667])

# %%
y_test.iloc[-1]
# Out:
# 180.0

# %%
y_pred =knn.predict(x_test)
y_pred
# Out:
# array([ 77.96333333,  39.84666667, 121.        , ...,  32.34166667,
#         62.66666667, 180.66666667])

# %% [markdown]
# ## -------------> COMPLETE <-------------
